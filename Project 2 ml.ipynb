# %% [markdown]
# # Project 2 — Visualization of World GDP and CO2 (Improved)
# **Student submission:** Bhuvan Gupta — Cohort 122
#
# This notebook follows Project 2 from the course PDF. It will attempt to fetch GDP per capita and CO2 per capita from the World Bank API for multiple countries and years. If internet is not available when you run it, it gracefully falls back to generating realistic synthetic data so all visualizations work and are varied (not constant).
